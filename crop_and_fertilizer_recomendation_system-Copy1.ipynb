# %% [markdown]
# CROP AND FERTILIZER RECOMMENDATION SYSTEM

# %% [raw]
# Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Reading the csv file (dataset of crop)
crop = pd.read_csv(r"C:\Users\rajashree\OneDrive\Desktop\crop and fertilizer RS\dataset\Crop_recommendation.csv")

# %%
#gives the first 5 rows and columns
crop.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
#gives the last 5 rows and columns
crop.tail()
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee

# %%
#shows the numper of rows and number of columns
crop.shape
# Out:
# (2200, 8)

# %%
#it checks if there is any null values in the dataset(TRUE if null vales FALSE if no null values)
crop.isnull()
# Out:
#           N      P      K  temperature  humidity     ph  rainfall  label
# 0     False  False  False        False     False  False     False  False
# 1     False  False  False        False     False  False     False  False
# 2     False  False  False        False     False  False     False  False
# 3     False  False  False        False     False  False     False  False
# 4     False  False  False        False     False  False     False  False
# ...     ...    ...    ...          ...       ...    ...       ...    ...
# 2195  False  False  False        False     False  False     False  False
# 2196  False  False  False        False     False  False     False  False
# 2197  False  False  False        False     False  False     False  False
# 2198  False  False  False        False     False  False     False  False
# 2199  False  False  False        False     False  False     False  False
#
# [2200 rows x 8 columns]

# %%
#shows the count of the null values
crop.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
#checks if there is any duplicate values( TRUE if yes else FALSE)
crop.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2195    False
# 2196    False
# 2197    False
# 2198    False
# 2199    False
# Length: 2200, dtype: bool

# %%
#shoes the count of duplicate values 
crop.duplicated().sum()
# Out:
# 0

# %%
#To check the statistics of the dataset
crop.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
crop.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
crop['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# jute           100
# cotton         100
# coconut        100
# papaya         100
# orange         100
# apple          100
# muskmelon      100
# watermelon     100
# grapes         100
# mango          100
# banana         100
# pomegranate    100
# lentil         100
# blackgram      100
# mungbean       100
# mothbeans      100
# pigeonpeas     100
# kidneybeans    100
# chickpea       100
# coffee         100
# Name: count, dtype: int64
